# %% [markdown]
# ##雲端硬碟設定指向

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !ls 'drive'
# Out:
# 'My Drive'  'Shared drives'

# %%
import os
path = "/content/drive/My Drive/Colab Notebooks/Bert/AML/"
os.chdir(path)

# %%
# !ls
# Out:
# albert	data.zip   trained_model   分類250.ipynb   名字預測.ipynb
# data	NER.ipynb  trained_model2  名字分類.ipynb

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# %% [markdown]
# ##下載Albert並放在albert目錄

# %%
# !git clone https://github.com/harry83528/albert-zh-for-pytorch-transformers.git albert
# Out:
# fatal: destination path 'albert' already exists and is not an empty directory.

# %% [markdown]
# ##建立訓練完模型儲存的資料夾

# %%
# !mkdir trained_model4

# %%
import torch
from torch.utils.data import TensorDataset
import pickle

# %%
import sys 
sys.path.append('.')
sys.path
# Out:
# ['',
#  '/env/python',
#  '/usr/lib/python36.zip',
#  '/usr/lib/python3.6',
#  '/usr/lib/python3.6/lib-dynload',
#  '/usr/local/lib/python3.6/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/usr/local/lib/python3.6/dist-packages/IPython/extensions',
#  '/root/.ipython',
#  '.']

# %%
# from albert.albert_zh import AlbertConfig, AlbertTokenizer, AlbertForSequenceClassification

# %% [markdown]
# ## 定義函式-選擇模型並加載設定

# %%
def use_model(model_name, config_file_path, model_file_path, vocab_file_path, num_labels):
    # 選擇模型並加載設定
    if(model_name == 'bert'):
        from transformers import BertConfig, BertForSequenceClassification, BertTokenizer
        model_config, model_class, model_tokenizer = (BertConfig, BertForSequenceClassification, BertTokenizer)
        config = model_config.from_pretrained(config_file_path,num_labels = num_labels)
        model = model_class.from_pretrained(model_file_path, from_tf=bool('.ckpt' in 'bert-base-chinese'), config=config)
        tokenizer = model_tokenizer(vocab_file=vocab_file_path)
        return model, tokenizer
    elif(model_name == 'albert'):
        from albert.albert_zh import AlbertConfig, AlbertTokenizer, AlbertForSequenceClassification
        model_config, model_class, model_tokenizer = (AlbertConfig, AlbertForSequenceClassification, AlbertTokenizer)
        config = model_config.from_pretrained(config_file_path,num_labels = num_labels)
        model = model_class.from_pretrained(model_file_path, config=config)
        tokenizer = model_tokenizer.from_pretrained(vocab_file_path)
        return model, tokenizer

# %% [markdown]
# ## 定義函式-準確率計算

# %%
def compute_accuracy(y_pred, y_target):
    # 計算正確率
    _, y_pred_indices = y_pred.max(dim=1)
    n_correct = torch.eq(y_pred_indices, y_target).sum().item()
    return n_correct / len(y_pred_indices) * 100

# %% [markdown]
# ## 定義函式-快速建立BERT INPUT( tokenizer.build_inputs_with_special_tokens() )

# %%
def to_bert_ids(tokenizer,q_input):
    # 將文字輸入轉換成對應的id編號
    #快速建立BERT INPUT
    return tokenizer.build_inputs_with_special_tokens(tokenizer.convert_tokens_to_ids(tokenizer.tokenize(q_input)))

# %% [markdown]
# ## 定義函式-轉換成tensor格式,並且建立dataset

# %%
#轉換成tensor格式,並且建立dataset
def make_dataset(input_ids, input_masks, input_segment_ids, answer_lables):
    all_input_ids = torch.tensor([input_id for input_id in input_ids], dtype=torch.long)
    all_input_masks = torch.tensor([input_mask for input_mask in input_masks], dtype=torch.long)
    all_input_segment_ids = torch.tensor([input_segment_id for input_segment_id in input_segment_ids], dtype=torch.long)
    all_answer_lables = torch.tensor([answer_lable for answer_lable in answer_lables], dtype=torch.long)    
    return TensorDataset(all_input_ids, all_input_masks, all_input_segment_ids, all_answer_lables)

# %% [markdown]
# ## 定義函式-分割資料

# %%
def split_dataset(full_dataset, split_rate=0.8):  
    train_size = int(split_rate * len(full_dataset))
    test_size = len(full_dataset) - train_size
    train_dataset, test_dataset = torch.utils.data.random_split(full_dataset, [train_size, test_size])
    return train_dataset,test_dataset

# %%
class DataDic(object):
    def __init__(self, answers):
        self.answers = answers #全部答案(含重複)
        self.answers_norepeat = sorted(list(set(answers))) # 不重複
        self.answers_types = len(self.answers_norepeat) # 總共多少類
        self.ans_list = [] # 用於查找id或是text的list
        self._make_dic() # 製作字典
    
    def _make_dic(self):
        for index_a,a in enumerate(self.answers_norepeat):
            if a != None:
                self.ans_list.append((index_a,a))

    def to_id(self,text):
        for ans_id,ans_text in self.ans_list:
            if text == ans_text:
                return ans_id

    def to_text(self,id):
        for ans_id,ans_text in self.ans_list:
            if id == ans_id:
                return ans_text

    @property
    def types(self):
        return self.answers_types
    
    @property
    def data(self):
        return self.answers

    def __len__(self):
        return len(self.answers)

# %% [markdown]
# ## 定義函式-創建BERT INPUT三層(Token Embeddings、Segment Embeddings、Position Embeddings)

# %%
import json
import csv
#創建BERT INPUT的三層
def convert_data_to_feature(tokenizer, train_data_path):
    questions = []
    answers = []
    with open(train_data_path, newline='') as csvfile:
      # 讀取 CSV 檔內容，將每一列轉成一個 dictionary
      rows = csv.DictReader(csvfile)
      # 以迴圈輸出指定欄位
      for row in rows:
        questions.append(row['name'])
        answers.append(row['label'])

    assert len(answers) == len(questions)
    print('questions len',len(questions))
    
    ans_dic = DataDic(answers)
    question_dic = DataDic(questions)

    q_tokens = []
    max_seq_len = 0
    for q in question_dic.data:
        bert_ids = to_bert_ids(tokenizer,q)
        if(len(bert_ids)>max_seq_len):
            max_seq_len = len(bert_ids)
        q_tokens.append(bert_ids)
        #反向查詢(還原)
        # print(tokenizer.convert_ids_to_tokens(tokenizer.build_inputs_with_special_tokens(tokenizer.convert_tokens_to_ids(tokenizer.tokenize(q)))))
    
    print("最長問句長度:",max_seq_len)
    assert max_seq_len <= 512 # 小於BERT-base長度限制

    # 補齊長度
    for q in q_tokens:
        while len(q)<max_seq_len:
            q.append(0)
    
    a_labels = []
    for a in ans_dic.data:
        a_labels.append(ans_dic.to_id(a))
        # print (ans_dic.to_id(a))
    
    # BERT input embedding
    answer_lables = a_labels
    input_ids = q_tokens
    input_masks = [[1]*max_seq_len for i in range(len(question_dic))]
    input_segment_ids = [[0]*max_seq_len for i in range(len(question_dic))]
    assert len(input_ids) == len(question_dic) and len(input_ids) == len(input_masks) and len(input_ids) == len(input_segment_ids)

    data_features = {'input_ids':input_ids,
                    'input_masks':input_masks,
                    'input_segment_ids':input_segment_ids,
                    'answer_lables':answer_lables,
                    'question_dic':question_dic,
                    'answer_dic':ans_dic}
    
    output = open('trained_model4/data_features.pkl', 'wb')
    pickle.dump(data_features,output)
    return data_features

# %%
# !pip install transformers==2.3.0
from torch.utils.data import DataLoader
import torch
from transformers import AdamW
# Out:
# Collecting transformers==2.3.0
#   Downloading https://files.pythonhosted.org/packages/50/10/aeefced99c8a59d828a92cc11d213e2743212d3641c87c82d61b035a7d5c/transformers-2.3.0-py3-none-any.whl (447kB)
#      |████████████████████████████████| 450kB 2.7MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from transformers==2.3.0) (1.18.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from transformers==2.3.0) (2.23.0)
# Collecting sacremoses
#   Downloading https://files.pythonhosted.org/packages/7d/34/09d19aff26edcc8eb2a01bed8e98f13a1537005d31e95233fd48216eed10/sacremoses-0.0.43.tar.gz (883kB)
#      |████████████████████████████████| 890kB 6.4MB/s
# Collecting sentencepiece
#   Downloading https://files.pythonhosted.org/packages/d4/a4/d0a884c4300004a78cca907a6ff9a5e9fe4f090f5d95ab341c53d28cbc58/sentencepiece-0.1.91-cp36-cp36m-manylinux1_x86_64.whl (1.1MB)
#      |████████████████████████████████| 1.1MB 15.4MB/s
# Requirement already satisfied: boto3 in /usr/local/lib/python3.6/dist-packages (from transformers==2.3.0) (1.14.20)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.6/dist-packages (from transformers==2.3.0) (2019.12.20)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from transformers==2.3.0) (4.41.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->transformers==2.3.0) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->transformers==2.3.0) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->transformers==2.3.0) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->transformers==2.3.0) (2020.6.20)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers==2.3.0) (1.12.0)
# Requirement already satisfied: click in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers==2.3.0) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers==2.3.0) (0.16.0)
# Requirement already satisfied: botocore<1.18.0,>=1.17.20 in /usr/local/lib/python3.6/dist-packages (from boto3->transformers==2.3.0) (1.17.20)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /usr/local/lib/python3.6/dist-packages (from boto3->transformers==2.3.0) (0.10.0)
# Requirement already satisfied: s3transfer<0.4.0,>=0.3.0 in /usr/local/lib/python3.6/dist-packages (from boto3->transformers==2.3.0) (0.3.3)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.6/dist-packages (from botocore<1.18.0,>=1.17.20->boto3->transformers==2.3.0) (2.8.1)
# Requirement already satisfied: docutils<0.16,>=0.10 in /usr/local/lib/python3.6/dist-packages (from botocore<1.18.0,>=1.17.20->boto3->transformers==2.3.0) (0.15.2)
# Building wheels for collected packages: sacremoses
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.43-cp36-none-any.whl size=893260 sha256=c6479b329b4089f1373cad1f7369f148fe80ce07cede5eb259a99aeabdd9deeb
#   Stored in directory: /root/.cache/pip/wheels/29/3c/fd/7ce5c3f0666dab31a50123635e6fb5e19ceb42ce38d4e58f45
# Successfully built sacremoses
# Installing collected packages: sacremoses, sentencepiece, transformers
# Successfully installed sacremoses-0.0.43 sentencepiece-0.1.91 transformers-2.3.0

# %% [markdown]
# ##主訓練架構

# %%
if __name__ == "__main__":

    #Step1:初始化加載模型 Start==================================================
    # BERT
#     model_setting = {
#         "model_name":"bert", 
#         "config_file_path":"bert-base-chinese", 
#         "model_file_path":"bert-base-chinese", 
#         "vocab_file_path":"bert-base-chinese-vocab.txt",
#         "num_labels":149  # 分幾類 
#     }    


    # ALBERT
    model_setting = {
        "model_name":"albert", 
        "config_file_path":"albert/albert_tiny/config.json", 
        "model_file_path":"albert/albert_tiny/pytorch_model.bin", 
        "vocab_file_path":"albert/albert_tiny/vocab.txt",
        "num_labels":2 # 分幾類
    }    

    #初始化加載模型
    model, tokenizer = use_model(**model_setting)
    #Step1:初始化加載模型 END====================================================


    #Step2:指定硬體裝置 Start====================================================
    # setting device
    #你電腦的 GPU 能否被 PyTorch 調用,如果不行就使用CPU 
    device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
    print("using device",device)
    model.to(device)
    #Step2:指定硬體裝置 END======================================================

    #Step3:將訓練資料讀入並且組建BERT輸入格式 Start===============================
    #呼叫寫好的convert_data_to_feature創建BERT INPUT的三層
    data_feature = convert_data_to_feature(tokenizer,'data/train_name_classification.csv')
    input_ids = data_feature['input_ids']
    input_masks = data_feature['input_masks']
    input_segment_ids = data_feature['input_segment_ids']
    answer_lables = data_feature['answer_lables']
    #Step3:將訓練資料讀入並且組建BERT輸入格式 END=================================


    #Step4:將組建好的輸入格式轉換成tensor格式，並且建立dataset與dataloader Srart==
    full_dataset = make_dataset(input_ids = input_ids, input_masks = input_masks, input_segment_ids = input_segment_ids, answer_lables = answer_lables)
    train_dataset, test_dataset = split_dataset(full_dataset, 0.9)
    train_dataloader = DataLoader(train_dataset,batch_size=16,shuffle=True)
    test_dataloader = DataLoader(test_dataset,batch_size=16,shuffle=True)
     #Step4:將組建好的輸入格式轉換成tensor格式，並且建立dataset與dataloader END===

    #準備優化器 Start===========================================================
    # Prepare optimizer and schedule (linear warmup and decay)
    no_decay = ['bias', 'LayerNorm.weight']
    optimizer_grouped_parameters = [
        {'params': [p for n, p in model.named_parameters() if not any(nd in n for nd in no_decay)], 'weight_decay': 0.0},
        {'params': [p for n, p in model.named_parameters() if any(nd in n for nd in no_decay)], 'weight_decay': 0.0}
        ]
    optimizer = AdamW(optimizer_grouped_parameters, lr=5e-6, eps=1e-8)
    # scheduler = WarmupLinearSchedule(optimizer, warmup_steps=args.warmup_steps, t_total=t_total)
    #準備優化器 End===========================================================


    #Step5:建構training loop、開始訓練 Start=====================================
    model.zero_grad() #梯度歸零
    for epoch in range(150):
        running_loss_val = 0.0
        running_acc = 0.0
        for batch_index, batch_dict in enumerate(train_dataloader):
            model.train()
            batch_dict = tuple(t.to(device) for t in batch_dict)
            outputs = model(
                batch_dict[0],
                # attention_mask=batch_dict[1],
                labels = batch_dict[3]
                )
            loss,logits = outputs[:2]
            loss.sum().backward()
            optimizer.step()
            # scheduler.step()  # Update learning rate schedule
            model.zero_grad()
            
            # compute the loss
            loss_t = loss.item()
            running_loss_val += (loss_t - running_loss_val) / (batch_index + 1)

            # compute the accuracy
            acc_t = compute_accuracy(logits, batch_dict[3])
            running_acc += (acc_t - running_acc) / (batch_index + 1)

            # log
            print("epoch:%2d batch:%4d train_loss:%2.4f train_acc:%3.4f"%(epoch+1, batch_index+1, running_loss_val, running_acc))
        
        running_loss_val = 0.0
        running_acc = 0.0
        for batch_index, batch_dict in enumerate(test_dataloader):
            model.eval()
            batch_dict = tuple(t.to(device) for t in batch_dict)
            outputs = model(
                batch_dict[0],
                # attention_mask=batch_dict[1],
                labels = batch_dict[3]
                )
            loss,logits = outputs[:2]
            
            # compute the loss
            loss_t = loss.item()
            running_loss_val += (loss_t - running_loss_val) / (batch_index + 1)

            # compute the accuracy
            acc_t = compute_accuracy(logits, batch_dict[3])
            running_acc += (acc_t - running_acc) / (batch_index + 1)

            # log
            print("epoch:%2d batch:%4d test_loss:%2.4f test_acc:%3.4f"%(epoch+1, batch_index+1, running_loss_val, running_acc))
    
    model_to_save = model.module if hasattr(model, 'module') else model  # Take care of distributed/parallel training
    model_to_save.save_pretrained('trained_model4')
    #Step5:建構training loop、開始訓練 END=====================================
# Out:
# using device cuda
# questions len 8131
# 最長問句長度: 31
# /pytorch/torch/csrc/utils/python_arg_parser.cpp:756: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# 	add_(Tensor other, *, Number alpha)
# Streaming output truncated to the last 5000 lines.
# epoch:141 batch:  92 train_loss:0.0001 train_acc:100.0000
# epoch:141 batch:  93 train_loss:0.0001 train_acc:100.0000
# epoch:141 batch:  94 train_loss:0.0001 train_acc:100.0000
# epoch:141 batch:  95 train_loss:0.0001 train_acc:100.0000
# epoch:141 batch:  96 train_loss:0.0001 train_acc:100.0000
# epoch:141 batch:  97 train_loss:0.0001 train_acc:100.0000
# epoch:141 batch:  98 train_loss:0.0001 train_acc:100.0000
# epoch:141 batch:  99 train_loss:0.0001 train_acc:100.0000
# epoch:141 batch: 100 train_loss:0.0001 train_acc:100.0000
# epoch:141 batch: 101 train_loss:0.0001 train_acc:100.0000
# epoch:141 batch: 102 train_loss:0.0001 train_acc:100.0000
# epoch:141 batch: 103 train_loss:0.0001 train_acc:100.0000
# epoch:141 batch: 104 train_loss:0.0001 train_acc:100.0000
# epoch:141 batch: 105 train_loss:0.0000 train_acc:100.0000
# epoch:141 batch: 106 train_loss:0.0000 train_acc:100.0000
# epoch:141 batch: 107 train_loss:0.0000 train_acc:100.0000
# epoch:141 batch: 108 train_loss:0.0000 train_acc:100.0000
# epoch:141 batch: 109 train_loss:0.0000 train_acc:100.0000
# epoch:141 batch: 110 train_loss:0.0000 train_acc:100.0000
# epoch:141 batch: 111 train_loss:0.0000 train_acc:100.0000
# epoch:141 batch: 112 train_loss:0.0000 train_acc:100.0000
# epoch:141 batch: 113 train_loss:0.0000 train_acc:100.0000
# epoch:141 batch: 114 train_loss:0.0000 train_acc:100.0000
# epoch:141 batch: 115 train_loss:0.0000 train_acc:100.0000
# epoch:141 batch: 116 train_loss:0.0000 train_acc:100.0000
# epoch:141 batch: 117 train_loss:0.0000 train_acc:100.0000
# epoch:141 batch: 118 train_loss:0.0000 train_acc:100.0000
# epoch:141 batch: 119 train_loss:0.0000 train_acc:100.0000
# epoch:141 batch: 120 train_loss:0.0000 train_acc:100.0000
# epoch:141 batch: 121 train_loss:0.0000 train_acc:100.0000
# epoch:141 batch: 122 train_loss:0.0000 train_acc:100.0000
# epoch:141 batch: 123 train_loss:0.0000 train_acc:100.0000
# epoch:141 batch: 124 train_loss:0.0000 train_acc:100.0000
# epoch:141 batch: 125 train_loss:0.0000 train_acc:100.0000
# epoch:141 batch: 126 train_loss:0.0000 train_acc:100.0000
# epoch:141 batch: 127 train_loss:0.0000 train_acc:100.0000
# epoch:141 batch: 128 train_loss:0.0000 train_acc:100.0000
# epoch:141 batch: 129 train_loss:0.0000 train_acc:100.0000
# epoch:141 batch: 130 train_loss:0.0000 train_acc:100.0000
# epoch:141 batch: 131 train_loss:0.0000 train_acc:100.0000
# epoch:141 batch: 132 train_loss:0.0000 train_acc:100.0000
# epoch:141 batch: 133 train_loss:0.0000 train_acc:100.0000
# epoch:141 batch: 134 train_loss:0.0000 train_acc:100.0000
# epoch:141 batch: 135 train_loss:0.0000 train_acc:100.0000
# epoch:141 batch: 136 train_loss:0.0000 train_acc:100.0000
# epoch:141 batch: 137 train_loss:0.0001 train_acc:100.0000
# epoch:141 batch: 138 train_loss:0.0000 train_acc:100.0000
# epoch:141 batch: 139 train_loss:0.0000 train_acc:100.0000
# epoch:141 batch: 140 train_loss:0.0000 train_acc:100.0000
# epoch:141 batch: 141 train_loss:0.0000 train_acc:100.0000
# epoch:141 batch: 142 train_loss:0.0000 train_acc:100.0000
# epoch:141 batch: 143 train_loss:0.0000 train_acc:100.0000
# epoch:141 batch: 144 train_loss:0.0000 train_acc:100.0000
# epoch:141 batch: 145 train_loss:0.0000 train_acc:100.0000
# epoch:141 batch: 146 train_loss:0.0000 train_acc:100.0000
# epoch:141 batch: 147 train_loss:0.0000 train_acc:100.0000
# epoch:141 batch: 148 train_loss:0.0000 train_acc:100.0000
# epoch:141 batch: 149 train_loss:0.0000 train_acc:100.0000
# epoch:141 batch: 150 train_loss:0.0000 train_acc:100.0000
# epoch:141 batch: 151 train_loss:0.0000 train_acc:100.0000
# epoch:141 batch: 152 train_loss:0.0000 train_acc:100.0000
# epoch:141 batch: 153 train_loss:0.0000 train_acc:100.0000
# epoch:141 batch: 154 train_loss:0.0000 train_acc:100.0000
# epoch:141 batch: 155 train_loss:0.0000 train_acc:100.0000
# epoch:141 batch: 156 train_loss:0.0000 train_acc:100.0000
# epoch:141 batch: 157 train_loss:0.0000 train_acc:100.0000
# epoch:141 batch: 158 train_loss:0.0000 train_acc:100.0000
# epoch:141 batch: 159 train_loss:0.0000 train_acc:100.0000
# epoch:141 batch: 160 train_loss:0.0000 train_acc:100.0000
# epoch:141 batch: 161 train_loss:0.0000 train_acc:100.0000
# epoch:141 batch: 162 train_loss:0.0000 train_acc:100.0000
# epoch:141 batch: 163 train_loss:0.0000 train_acc:100.0000
# epoch:141 batch: 164 train_loss:0.0000 train_acc:100.0000
# epoch:141 batch: 165 train_loss:0.0002 train_acc:100.0000
# epoch:141 batch: 166 train_loss:0.0002 train_acc:100.0000
# epoch:141 batch: 167 train_loss:0.0002 train_acc:100.0000
# epoch:141 batch: 168 train_loss:0.0002 train_acc:100.0000
# epoch:141 batch: 169 train_loss:0.0002 train_acc:100.0000
# epoch:141 batch: 170 train_loss:0.0002 train_acc:100.0000
# epoch:141 batch: 171 train_loss:0.0002 train_acc:100.0000
# epoch:141 batch: 172 train_loss:0.0002 train_acc:100.0000
# epoch:141 batch: 173 train_loss:0.0002 train_acc:100.0000
# epoch:141 batch: 174 train_loss:0.0002 train_acc:100.0000
# epoch:141 batch: 175 train_loss:0.0002 train_acc:100.0000
# epoch:141 batch: 176 train_loss:0.0002 train_acc:100.0000
# epoch:141 batch: 177 train_loss:0.0002 train_acc:100.0000
# epoch:141 batch: 178 train_loss:0.0002 train_acc:100.0000
# epoch:141 batch: 179 train_loss:0.0002 train_acc:100.0000
# epoch:141 batch: 180 train_loss:0.0002 train_acc:100.0000
# epoch:141 batch: 181 train_loss:0.0002 train_acc:100.0000
# epoch:141 batch: 182 train_loss:0.0002 train_acc:100.0000
# epoch:141 batch: 183 train_loss:0.0002 train_acc:100.0000
# epoch:141 batch: 184 train_loss:0.0002 train_acc:100.0000
# epoch:141 batch: 185 train_loss:0.0002 train_acc:100.0000
# epoch:141 batch: 186 train_loss:0.0002 train_acc:100.0000
# epoch:141 batch: 187 train_loss:0.0002 train_acc:100.0000
# epoch:141 batch: 188 train_loss:0.0002 train_acc:100.0000
# epoch:141 batch: 189 train_loss:0.0002 train_acc:100.0000
# epoch:141 batch: 190 train_loss:0.0002 train_acc:100.0000
# epoch:141 batch: 191 train_loss:0.0002 train_acc:100.0000
# epoch:141 batch: 192 train_loss:0.0002 train_acc:100.0000
# epoch:141 batch: 193 train_loss:0.0002 train_acc:100.0000
# epoch:141 batch: 194 train_loss:0.0002 train_acc:100.0000
# epoch:141 batch: 195 train_loss:0.0002 train_acc:100.0000
# epoch:141 batch: 196 train_loss:0.0002 train_acc:100.0000
# epoch:141 batch: 197 train_loss:0.0002 train_acc:100.0000
# epoch:141 batch: 198 train_loss:0.0002 train_acc:100.0000
# epoch:141 batch: 199 train_loss:0.0002 train_acc:100.0000
# epoch:141 batch: 200 train_loss:0.0002 train_acc:100.0000
# epoch:141 batch: 201 train_loss:0.0002 train_acc:100.0000
# epoch:141 batch: 202 train_loss:0.0002 train_acc:100.0000
# epoch:141 batch: 203 train_loss:0.0002 train_acc:100.0000
# epoch:141 batch: 204 train_loss:0.0002 train_acc:100.0000
# epoch:141 batch: 205 train_loss:0.0003 train_acc:100.0000
# epoch:141 batch: 206 train_loss:0.0002 train_acc:100.0000
# epoch:141 batch: 207 train_loss:0.0002 train_acc:100.0000
# epoch:141 batch: 208 train_loss:0.0002 train_acc:100.0000
# epoch:141 batch: 209 train_loss:0.0002 train_acc:100.0000
# epoch:141 batch: 210 train_loss:0.0002 train_acc:100.0000
# epoch:141 batch: 211 train_loss:0.0002 train_acc:100.0000
# epoch:141 batch: 212 train_loss:0.0002 train_acc:100.0000
# epoch:141 batch: 213 train_loss:0.0002 train_acc:100.0000
# epoch:141 batch: 214 train_loss:0.0002 train_acc:100.0000
# epoch:141 batch: 215 train_loss:0.0002 train_acc:100.0000
# epoch:141 batch: 216 train_loss:0.0002 train_acc:100.0000
# epoch:141 batch: 217 train_loss:0.0002 train_acc:100.0000
# epoch:141 batch: 218 train_loss:0.0002 train_acc:100.0000
# epoch:141 batch: 219 train_loss:0.0002 train_acc:100.0000
# epoch:141 batch: 220 train_loss:0.0002 train_acc:100.0000
# epoch:141 batch: 221 train_loss:0.0002 train_acc:100.0000
# epoch:141 batch: 222 train_loss:0.0002 train_acc:100.0000
# epoch:141 batch: 223 train_loss:0.0002 train_acc:100.0000
# epoch:141 batch: 224 train_loss:0.0002 train_acc:100.0000
# epoch:141 batch: 225 train_loss:0.0002 train_acc:100.0000
# epoch:141 batch: 226 train_loss:0.0002 train_acc:100.0000
# epoch:141 batch: 227 train_loss:0.0002 train_acc:100.0000
# epoch:141 batch: 228 train_loss:0.0002 train_acc:100.0000
# epoch:141 batch: 229 train_loss:0.0002 train_acc:100.0000
# epoch:141 batch:
# epoch:142 batch: 388 train_loss:0.0003 train_acc:99.9839
# epoch:142 batch: 389 train_loss:0.0003 train_acc:99.9839
# epoch:142 batch: 390 train_loss:0.0003 train_acc:99.9840
# epoch:142 batch: 391 train_loss:0.0003 train_acc:99.9840
# epoch:142 batch: 392 train_loss:0.0004 train_acc:99.9681
# epoch:142 batch: 393 train_loss:0.0004 train_acc:99.9682
# epoch:142 batch: 394 train_loss:0.0004 train_acc:99.9683
# epoch:142 batch: 395 train_loss:0.0004 train_acc:99.9684
# epoch:142 batch: 396 train_loss:0.0004 train_acc:99.9684
# epoch:142 batch: 397 train_loss:0.0004 train_acc:99.9685
# epoch:142 batch: 398 train_loss:0.0004 train_acc:99.9686
# epoch:142 batch: 399 train_loss:0.0004 train_acc:99.9687
# epoch:142 batch: 400 train_loss:0.0004 train_acc:99.9688
# epoch:142 batch: 401 train_loss:0.0004 train_acc:99.9688
# epoch:142 batch: 402 train_loss:0.0004 train_acc:99.9689
# epoch:142 batch: 403 train_loss:0.0004 train_acc:99.9690
# epoch:142 batch: 404 train_loss:0.0004 train_acc:99.9691
# epoch:142 batch: 405 train_loss:0.0004 train_acc:99.9691
# epoch:142 batch: 406 train_loss:0.0004 train_acc:99.9692
# epoch:142 batch: 407 train_loss:0.0004 train_acc:99.9693
# epoch:142 batch: 408 train_loss:0.0004 train_acc:99.9694
# epoch:142 batch: 409 train_loss:0.0004 train_acc:99.9694
# epoch:142 batch: 410 train_loss:0.0004 train_acc:99.9695
# epoch:142 batch: 411 train_loss:0.0004 train_acc:99.9696
# ...
# epoch:150 batch: 228 train_loss:0.0003 train_acc:99.9726
# epoch:150 batch: 229 train_loss:0.0003 train_acc:99.9727
# epoch:150 batch: 230 train_loss:0.0003 train_acc:99.9728
# epoch:150 batch: 231 train_loss:0.0003 train_acc:99.9729
# epoch:150 batch: 232 train_loss:0.0003 train_acc:99.9731
# epoch:150 batch: 233 train_loss:0.0003 train_acc:99.9732
# epoch:150 batch: 234 train_loss:0.0003 train_acc:99.9733
# epoch:150 batch: 235 train_loss:0.0003 train_acc:99.9734
# epoch:150 batch: 236 train_loss:0.0003 train_acc:99.9735
# epoch:150 batch: 237 train_loss:0.0003 train_acc:99.9736
# epoch:150 batch: 238 train_loss:0.0003 train_acc:99.9737
# epoch:150 batch: 239 train_loss:0.0003 train_acc:99.9738
# epoch:150 batch: 240 train_loss:0.0003 train_acc:99.9740
# epoch:150 batch: 241 train_loss:0.0003 train_acc:99.9741
# epoch:150 batch: 242 train_loss:0.0003 train_acc:99.9742
# epoch:150 batch: 243 train_loss:0.0003 train_acc:99.9743
# epoch:150 batch: 244 train_loss:0.0003 train_acc:99.9744
# epoch:150 batch: 245 train_loss:0.0003 train_acc:99.9745
# epoch:150 batch: 246 train_loss:0.0003 train_acc:99.9746
# epoch:150 batch: 247 train_loss:0.0003 train_acc:99.9747
# epoch:150 batch: 248 train_loss:0.0003 train_acc:99.9748
# epoch:150 batch: 249 train_loss:0.0003 train_acc:99.9749
# epoch:150 batch: 250 train_loss:0.0003 train_acc:99.9750
# epoch:150 batch: 251 train_loss:0.0003 train_acc:99.9751
# epoch:150 batch: 252 train_loss:0.0003 train_acc:99.9752
# epoch:150 batch: 253 train_loss:0.0003 train_acc:99.9753
# epoch:150 batch: 254 train_loss:0.0003 train_acc:99.9754
# epoch:150 batch: 255 train_loss:0.0003 train_acc:99.9755
# epoch:150 batch: 256 train_loss:0.0003 train_acc:99.9756
# epoch:150 batch: 257 train_loss:0.0003 train_acc:99.9757
# epoch:150 batch: 258 train_loss:0.0003 train_acc:99.9758
# epoch:150 batch: 259 train_loss:0.0003 train_acc:99.9759
# epoch:150 batch: 260 train_loss:0.0003 train_acc:99.9760
# epoch:150 batch: 261 train_loss:0.0003 train_acc:99.9761
# epoch:150 batch: 262 train_loss:0.0003 train_acc:99.9761
# epoch:150 batch: 263 train_loss:0.0003 train_acc:99.9762
# epoch:150 batch: 264 train_loss:0.0003 train_acc:99.9763
# epoch:150 batch: 265 train_loss:0.0003 train_acc:99.9764
# epoch:150 batch: 266 train_loss:0.0003 train_acc:99.9765
# epoch:150 batch: 267 train_loss:0.0003 train_acc:99.9766
# epoch:150 batch: 268 train_loss:0.0003 train_acc:99.9767
# epoch:150 batch: 269 train_loss:0.0003 train_acc:99.9768
# epoch:150 batch: 270 train_loss:0.0003 train_acc:99.9769
# epoch:150 batch: 271 train_loss:0.0003 train_acc:99.9769
# epoch:150 batch: 272 train_loss:0.0003 train_acc:99.9770
# epoch:150 batch: 273 train_loss:0.0003 train_acc:99.9771
# epoch:150 batch: 274 train_loss:0.0003 train_acc:99.9772
# epoch:150 batch: 275 train_loss:0.0003 train_acc:99.9773
# epoch:150 batch: 276 train_loss:0.0003 train_acc:99.9774
# epoch:150 batch: 277 train_loss:0.0003 train_acc:99.9774
# epoch:150 batch: 278 train_loss:0.0003 train_acc:99.9775
# epoch:150 batch: 279 train_loss:0.0003 train_acc:99.9776
# epoch:150 batch: 280 train_loss:0.0003 train_acc:99.9777
# epoch:150 batch: 281 train_loss:0.0003 train_acc:99.9778
# epoch:150 batch: 282 train_loss:0.0003 train_acc:99.9778
# epoch:150 batch: 283 train_loss:0.0003 train_acc:99.9779
# epoch:150 batch: 284 train_loss:0.0003 train_acc:99.9780
# epoch:150 batch: 285 train_loss:0.0003 train_acc:99.9781
# epoch:150 batch: 286 train_loss:0.0003 train_acc:99.9781
# epoch:150 batch: 287 train_loss:0.0003 train_acc:99.9782
# epoch:150 batch: 288 train_loss:0.0003 train_acc:99.9783
# epoch:150 batch: 289 train_loss:0.0003 train_acc:99.9784
# epoch:150 batch: 290 train_loss:0.0003 train_acc:99.9784
# epoch:150 batch: 291 train_loss:0.0003 train_acc:99.9785
# epoch:150 batch: 292 train_loss:0.0003 train_acc:99.9786
# epoch:150 batch: 293 train_loss:0.0003 train_acc:99.9787
# epoch:150 batch: 294 train_loss:0.0003 train_acc:99.9787
# epoch:150 batch: 295 train_loss:0.0003 train_acc:99.9788
# epoch:150 batch: 296 train_loss:0.0003 train_acc:99.9789
# epoch:150 batch: 297 train_loss:0.0003 train_acc:99.9790
# epoch:150 batch: 298 train_loss:0.0003 train_acc:99.9790
# epoch:150 batch: 299 train_loss:0.0003 train_acc:99.9791
# epoch:150 batch: 300 train_loss:0.0003 train_acc:99.9792
# epoch:150 batch: 301 train_loss:0.0003 train_acc:99.9792
# epoch:150 batch: 302 train_loss:0.0003 train_acc:99.9793
# epoch:150 batch: 303 train_loss:0.0003 train_acc:99.9794
# epoch:150 batch: 304 train_loss:0.0003 train_acc:99.9794
# epoch:150 batch: 305 train_loss:0.0003 train_acc:99.9795
# epoch:150 batch: 306 train_loss:0.0003 train_acc:99.9796
# epoch:150 batch: 307 train_loss:0.0003 train_acc:99.9796
# epoch:150 batch: 308 train_loss:0.0003 train_acc:99.9797
# epoch:150 batch: 309 train_loss:0.0003 train_acc:99.9798
# epoch:150 batch: 310 train_loss:0.0003 train_acc:99.9798
# epoch:150 batch: 311 train_loss:0.0003 train_acc:99.9799
# epoch:150 batch: 312 train_loss:0.0003 train_acc:99.9800
# epoch:150 batch: 313 train_loss:0.0003 train_acc:99.9800
# epoch:150 batch: 314 train_loss:0.0003 train_acc:99.9801
# epoch:150 batch: 315 train_loss:0.0003 train_acc:99.9802
# epoch:150 batch: 316 train_loss:0.0003 train_acc:99.9802
# epoch:150 batch: 317 train_loss:0.0003 train_acc:99.9803
# epoch:150 batch: 318 train_loss:0.0003 train_acc:99.9803
# epoch:150 batch: 319 train_loss:0.0003 train_acc:99.9804
# epoch:150 batch: 320 train_loss:0.0003 train_acc:99.9805
# epoch:150 batch: 321 train_loss:0.0003 train_acc:99.9805
# epoch:150 batch: 322 train_loss:0.0003 train_acc:99.9806
# epoch:150 batch: 323 train_loss:0.0003 train_acc:99.9807
# epoch:150 batch: 324 train_loss:0.0003 train_acc:99.9807
# epoch:150 batch: 325 train_loss:0.0003 train_acc:99.9808
# epoch:150 batch: 326 train_loss:0.0003 train_acc:99.9808
# epoch:150 batch: 327 train_loss:0.0003 train_acc:99.9809
# epoch:150 batch: 328 train_loss:0.0003 train_acc:99.9809
# epoch:150 batch: 329 train_loss:0.0003 train_acc:99.9810
# epoch:150 batch: 330 train_loss:0.0003 train_acc:99.9811
# epoch:150 batch: 331 train_loss:0.0003 train_acc:99.9811
# epoch:150 batch: 332 train_loss:0.0003 train_acc:99.9812
# epoch:150 batch: 333 train_loss:0.0003 train_acc:99.9812
# epoch:150 batch: 334 train_loss:0.0003 train_acc:99.9813
# epoch:150 batch: 335 train_loss:0.0003 train_acc:99.9813
# epoch:150 batch: 336 train_loss:0.0003 train_acc:99.9814
# epoch:150 batch: 337 train_loss:0.0003 train_acc:99.9815
# epoch:150 batch: 338 train_loss:0.0003 train_acc:99.9815
# epoch:150 batch: 339 train_loss:0.0003 train_acc:99.9816
# epoch:150 batch: 340 train_loss:0.0003 train_acc:99.9816
# epoch:150 batch: 341 train_loss:0.0003 train_acc:99.9817
# epoch:150 batch: 342 train_loss:0.0003 train_acc:99.9817
# epoch:150 batch: 343 train_loss:0.0003 train_acc:99.9818
# epoch:150 batch: 344 train_loss:0.0003 train_acc:99.9818
# epoch:150 batch: 345 train_loss:0.0003 train_acc:99.9819
# epoch:150 batch: 346 train_loss:0.0003 train_acc:99.9819
# epoch:150 batch: 347 train_loss:0.0003 train_acc:99.9820
# epoch:150 batch: 348 train_loss:0.0003 train_acc:99.9820
# epoch:150 batch: 349 train_loss:0.0003 train_acc:99.9821
# epoch:150 batch: 350 train_loss:0.0003 train_acc:99.9821
# epoch:150 batch: 351 train_loss:0.0003 train_acc:99.9822
# epoch:150 batch: 352 train_loss:0.0003 train_acc:99.9822
# epoch:150 batch: 353 train_loss:0.0002 train_acc:99.9823
# epoch:150 batch: 354 train_loss:0.0003 train_acc:99.9823
# epoch:150 batch: 355 train_loss:0.0003 train_acc:99.9824
# epoch:150 batch: 356 train_loss:0.0003 train_acc:99.9824
# epoch:150 batch: 357 train_loss:0.0003 train_acc:99.9825
# epoch:150 batch: 358 train_loss:0.0003 train_acc:99.9825
# epoch:150 batch: 359 train_loss:0.0003 train_acc:99.9826
# epoch:150 batch: 360 train_loss:0.0003 train_acc:99.9826
# epoch:150 batch: 361 train_loss:0.0003 train_acc:99.9827
# epoch:150 batch: 362 train_loss:0.0003 train_acc:99.9827
# epoch:150 batch: 363 train_loss:0.0003 train_acc:99.9828
# epoch:150 batch: 364 train_loss:0.0003 train_acc:99.9828
# epoch:150 batch: 365 train_loss:0.0003 train_acc:99.9829
# epoch:150 batch: 366 train_loss:0.0003 train_acc:99.9829
# epoch:150 batch: 367 train_loss:0.0003 train_acc:99.9830
# epoch:150 batch: 368 train_loss:0.0003 train_acc:99.9830
# epoch:150 batch: 369 train_loss:0.0003 train_acc:99.9831
# epoch:150 batch: 370 train_loss:0.0003 train_acc:99.9831
# epoch:150 batch: 371 train_loss:0.0003 train_acc:99.9832
# epoch:150 batch: 372 train_loss:0.0003 train_acc:99.9832
# epoch:150 batch: 373 train_loss:0.0003 train_acc:99.9832
# epoch:150 batch: 374 train_loss:0.0003 train_acc:99.9833
# epoch:150 batch: 375 train_loss:0.0003 train_acc:99.9833
# epoch:150 batch: 376 train_loss:0.0003 train_acc:99.9834
# epoch:150 batch: 377 train_loss:0.0003 train_acc:99.9834
# epoch:150 batch: 378 train_loss:0.0003 train_acc:99.9835
# epoch:150 batch: 379 train_loss:0.0003 train_acc:99.9835
# epoch:150 batch: 380 train_loss:0.0004 train_acc:99.9836
# epoch:150 batch: 381 train_loss:0.0004 train_acc:99.9836
# epoch:150 batch: 382 train_loss:0.0004 train_acc:99.9836
# epoch:150 batch: 383 train_loss:0.0004 train_acc:99.9837
# epoch:150 batch: 384 train_loss:0.0004 train_acc:99.9837
# epoch:150 batch: 385 train_loss:0.0004 train_acc:99.9838
# epoch:150 batch: 386 train_loss:0.0004 train_acc:99.9838
# epoch:150 batch: 387 train_loss:0.0004 train_acc:99.9839
# epoch:150 batch: 388 train_loss:0.0004 train_acc:99.9839
# epoch:150 batch: 389 train_loss:0.0004 train_acc:99.9839
# epoch:150 batch: 390 train_loss:0.0004 train_acc:99.9840
# epoch:150 batch: 391 train_loss:0.0004 train_acc:99.9840
# epoch:150 batch: 392 train_loss:0.0004 train_acc:99.9841
# epoch:150 batch: 393 train_loss:0.0004 train_acc:99.9841
# epoch:150 batch: 394 train_loss:0.0004 train_acc:99.9841
# epoch:150 batch: 395 train_loss:0.0004 train_acc:99.9842
# epoch:150 batch: 396 train_loss:0.0004 train_acc:99.9842
# epoch:150 batch: 397 train_loss:0.0004 train_acc:99.9843
# epoch:150 batch: 398 train_loss:0.0004 train_acc:99.9843
# epoch:150 batch: 399 train_loss:0.0004 train_acc:99.9843
# epoch:150 batch: 400 train_loss:0.0004 train_acc:99.9844
# epoch:150 batch: 401 train_loss:0.0004 train_acc:99.9844
# epoch:150 batch: 402 train_loss:0.0004 train_acc:99.9845
# epoch:150 batch: 403 train_loss:0.0004 train_acc:99.9845
# epoch:150 batch: 404 train_loss:0.0004 train_acc:99.9845
# epoch:150 batch: 405 train_loss:0.0004 train_acc:99.9846
# epoch:150 batch: 406 train_loss:0.0004 train_acc:99.9846
# epoch:150 batch: 407 train_loss:0.0004 train_acc:99.9846
# epoch:150 batch: 408 train_loss:0.0004 train_acc:99.9847
# epoch:150 batch: 409 train_loss:0.0004 train_acc:99.9847
# epoch:150 batch: 410 train_loss:0.0004 train_acc:99.9848
# epoch:150 batch: 411 train_loss:0.0004 train_acc:99.9848
# epoch:150 batch: 412 train_loss:0.0004 train_acc:99.9848
# epoch:150 batch: 413 train_loss:0.0004 train_acc:99.9849
# epoch:150 batch: 414 train_loss:0.0004 train_acc:99.9849
# epoch:150 batch: 415 train_loss:0.0004 train_acc:99.9849
# epoch:150 batch: 416 train_loss:0.0004 train_acc:99.9850
# epoch:150 batch: 417 train_loss:0.0004 train_acc:99.9850
# epoch:150 batch: 418 train_loss:0.0004 train_acc:99.9850
# epoch:150 batch: 419 train_loss:0.0004 train_acc:99.9851
# epoch:150 batch: 420 train_loss:0.0004 train_acc:99.9851
# epoch:150 batch: 421 train_loss:0.0004 train_acc:99.9852
# epoch:150 batch: 422 train_loss:0.0004 train_acc:99.9852
# epoch:150 batch: 423 train_loss:0.0004 train_acc:99.9852
# epoch:150 batch: 424 train_loss:0.0004 train_acc:99.9853
# epoch:150 batch: 425 train_loss:0.0004 train_acc:99.9853
# epoch:150 batch: 426 train_loss:0.0004 train_acc:99.9853
# epoch:150 batch: 427 train_loss:0.0004 train_acc:99.9854
# epoch:150 batch: 428 train_loss:0.0004 train_acc:99.9854
# epoch:150 batch: 429 train_loss:0.0004 train_acc:99.9854
# epoch:150 batch: 430 train_loss:0.0004 train_acc:99.9855
# epoch:150 batch: 431 train_loss:0.0004 train_acc:99.9855
# epoch:150 batch: 432 train_loss:0.0004 train_acc:99.9855
# epoch:150 batch: 433 train_loss:0.0004 train_acc:99.9856
# epoch:150 batch: 434 train_loss:0.0004 train_acc:99.9856
# epoch:150 batch: 435 train_loss:0.0004 train_acc:99.9856
# epoch:150 batch: 436 train_loss:0.0004 train_acc:99.9857
# epoch:150 batch: 437 train_loss:0.0003 train_acc:99.9857
# epoch:150 batch: 438 train_loss:0.0003 train_acc:99.9857
# epoch:150 batch: 439 train_loss:0.0003 train_acc:99.9858
# epoch:150 batch: 440 train_loss:0.0003 train_acc:99.9858
# epoch:150 batch: 441 train_loss:0.0003 train_acc:99.9858
# epoch:150 batch: 442 train_loss:0.0003 train_acc:99.9859
# epoch:150 batch: 443 train_loss:0.0003 train_acc:99.9859
# epoch:150 batch: 444 train_loss:0.0003 train_acc:99.9859
# epoch:150 batch: 445 train_loss:0.0003 train_acc:99.9860
# epoch:150 batch: 446 train_loss:0.0003 train_acc:99.9860
# epoch:150 batch: 447 train_loss:0.0003 train_acc:99.9860
# epoch:150 batch: 448 train_loss:0.0003 train_acc:99.9860
# epoch:150 batch: 449 train_loss:0.0003 train_acc:99.9861
# epoch:150 batch: 450 train_loss:0.0003 train_acc:99.9861
# epoch:150 batch: 451 train_loss:0.0003 train_acc:99.9861
# epoch:150 batch: 452 train_loss:0.0003 train_acc:99.9862
# epoch:150 batch: 453 train_loss:0.0003 train_acc:99.9862
# epoch:150 batch: 454 train_loss:0.0003 train_acc:99.9862
# epoch:150 batch: 455 train_loss:0.0003 train_acc:99.9863
# epoch:150 batch: 456 train_loss:0.0003 train_acc:99.9863
# epoch:150 batch: 457 train_loss:0.0003 train_acc:99.9863
# epoch:150 batch: 458 train_loss:0.0003 train_acc:99.9864
# epoch:150 batch:   1 test_loss:1.6163 test_acc:81.2500
# epoch:150 batch:   2 test_loss:0.8082 test_acc:90.6250
# epoch:150 batch:   3 test_loss:0.9303 test_acc:89.5833
# epoch:150 batch:   4 test_loss:0.9394 test_acc:89.0625
# epoch:150 batch:   5 test_loss:0.8891 test_acc:90.0000
# epoch:150 batch:   6 test_loss:0.8725 test_acc:89.5833
# epoch:150 batch:   7 test_loss:0.8437 test_acc:90.1786
# epoch:150 batch:   8 test_loss:0.7383 test_acc:91.4062
# epoch:150 batch:   9 test_loss:0.6563 test_acc:92.3611
# epoch:150 batch:  10 test_loss:0.5951 test_acc:92.5000
# epoch:150 batch:  11 test_loss:0.5410 test_acc:93.1818
# epoch:150 batch:  12 test_loss:0.5508 test_acc:93.2292
# epoch:150 batch:  13 test_loss:0.5084 test_acc:93.7500
# epoch:150 batch:  14 test_loss:0.4721 test_acc:94.1964
# epoch:150 batch:  15 test_loss:0.4407 test_acc:94.5833
# epoch:150 batch:  16 test_loss:0.4561 test_acc:94.5312
# epoch:150 batch:  17 test_loss:0.4294 test_acc:94.8529
# epoch:150 batch:  18 test_loss:0.4236 test_acc:94.7917
# epoch:150 batch:  19 test_loss:0.5206 test_acc:93.7500
# epoch:150 batch:  20 test_loss:0.5273 test_acc:93.7500
# epoch:150 batch:  21 test_loss:0.5964 test_acc:92.8571
# epoch:150 batch:  22 test_loss:0.5717 test_acc:92.8977
# epoch:150 batch:  23 test_loss:0.5942 test_acc:92.3913
# epoch:150 batch:  24 test_loss:0.5908 test_acc:92.1875
# epoch:150 batch:  25 test_loss:0.6859 test_acc:91.2500
# epoch:150 batch:  26 test_loss:0.6597 test_acc:91.5865
# epoch:150 batch:  27 test_loss:0.6667 test_acc:91.4352
# epoch:150 batch:  28 test_loss:0.6877 test_acc:91.0714
# epoch:150 batch:  29 test_loss:0.6772 test_acc:91.1638
# epoch:150 batch:  30 test_loss:0.7158 test_acc:90.8333
# epoch:150 batch:  31 test_loss:0.7198 test_acc:90.7258
# epoch:150 batch:  32 test_loss:0.7229 test_acc:90.6250
# epoch:150 batch:  33 test_loss:0.7055 test_acc:90.7197
# epoch:150 batch:  34 test_loss:0.6966 test_acc:90.6250
# epoch:150 batch:  35 test_loss:0.6966 test_acc:90.7143
# epoch:150 batch:  36 test_loss:0.7038 test_acc:90.6250
# epoch:150 batch:  37 test_loss:0.6848 test_acc:90.8784
# epoch:150 batch:  38 test_loss:0.7056 test_acc:90.6250
# epoch:150 batch:  39 test_loss:0.7018 test_acc:90.7051
# epoch:150 batch:  40 test_loss:0.7014 test_acc:90.7813
# epoch:150 batch:  41 test_loss:0.7147 test_acc:90.7012
# epoch:150 batch:  42 test_loss:0.7048 test_acc:90.7738
# epoch:150 batch:  43 test_loss:0.6900 test_acc:90.8430
# epoch:150 batch:  44 test_loss:0.6897 test_acc:90.9091
# epoch:150 batch:  45 test_loss:0.6835 test_acc:90.9722
# epoch:150 batch:  46 test_loss:0.6716 test_acc:91.0326
# epoch:150 batch:  47 test_loss:0.6585 test_acc:91.0904
# epoch:150 batch:  48 test_loss:0.6590 test_acc:91.0156
# epoch:150 batch:  49 test_loss:0.6728 test_acc:90.9439
# epoch:150 batch:  50 test_loss:0.6683 test_acc:91.0000
# epoch:150 batch:  51 test_loss:0.6561 test_acc:91.1765

# %%
# load and init
pkl_file = open('trained_model4/data_features.pkl', 'rb')
data_features = pickle.load(pkl_file)
answer_dic = data_features['answer_dic']

# %%
model_setting2 = {
    "model_name":"albert", 
    "config_file_path":"trained_model4/config.json", 
    "model_file_path":"trained_model4/pytorch_model.bin", 
    "vocab_file_path":"albert/albert_tiny/vocab.txt",
    "num_labels":2 # 分幾類
}    
model, tokenizer = use_model(**model_setting2)
model.eval()

#
q_inputs = ['韓國瑜']
for q_input in q_inputs:
    bert_ids = to_bert_ids(tokenizer,q_input)
    print('len(bert_ids)',len(bert_ids))
    assert len(bert_ids) <= 512
    input_ids = torch.LongTensor(bert_ids).unsqueeze(0)

    # predict
    outputs = model(input_ids)
    predicts = outputs[:2]
    predicts = predicts[0]
    max_val = torch.max(predicts)
    label = (predicts == max_val).nonzero().numpy()[0][1]
    ans_label = answer_dic.to_text(label)
    
    print(q_input)
    print(ans_label)
    print()
# Out:
# len(bert_ids) 5
# 韓國瑜
# 0
